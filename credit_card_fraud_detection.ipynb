# %%
import pandas as pd

df = pd.read_csv("data/raw/creditcard.csv")
df.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %%
df.shape
# Out:
# (284807, 31)

# %%
df.columns
# Out:
# Index(['Time', 'V1', 'V2', 'V3', 'V4', 'V5', 'V6', 'V7', 'V8', 'V9', 'V10',
#        'V11', 'V12', 'V13', 'V14', 'V15', 'V16', 'V17', 'V18', 'V19', 'V20',
#        'V21', 'V22', 'V23', 'V24', 'V25', 'V26', 'V27', 'V28', 'Amount',
#        'Class'],
#       dtype='str')

# %%
df["Class"].value_counts()
# Out:
# Class
# 0    284315
# 1       492
# Name: count, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 284807 entries, 0 to 284806
# Data columns (total 31 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Time    284807 non-null  float64
#  1   V1      284807 non-null  float64
#  2   V2      284807 non-null  float64
#  3   V3      284807 non-null  float64
#  4   V4      284807 non-null  float64
#  5   V5      284807 non-null  float64
#  6   V6      284807 non-null  float64
#  7   V7      284807 non-null  float64
#  8   V8      284807 non-null  float64
#  9   V9      284807 non-null  float64
#  10  V10     284807 non-null  float64
#  11  V11     284807 non-null  float64
#  12  V12     284807 non-null  float64
#  13  V13     284807 non-null  float64
#  14  V14     284807 non-null  float64
#  15  V15     284807 non-null  float64
#  16  V16     284807 non-null  float64
#  17  V17     284807 non-null  float64
#  18  V18     284807 non-null  float64
#  19  V19     284807 non-null  float64
# ...

# %%
df.isnull().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# Amount    0
# Class     0
# dtype: int64

# %%
df.describe()
# Out:
#                 Time            V1            V2            V3            V4  \
# count  284807.000000  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean    94813.859575  1.175161e-15  3.384974e-16 -1.379537e-15  2.094852e-15
# std     47488.145955  1.958696e+00  1.651309e+00  1.516255e+00  1.415869e+00
# min         0.000000 -5.640751e+01 -7.271573e+01 -4.832559e+01 -5.683171e+00
# 25%     54201.500000 -9.203734e-01 -5.985499e-01 -8.903648e-01 -8.486401e-01
# 50%     84692.000000  1.810880e-02  6.548556e-02  1.798463e-01 -1.984653e-02
# 75%    139320.500000  1.315642e+00  8.037239e-01  1.027196e+00  7.433413e-01
# max    172792.000000  2.454930e+00  2.205773e+01  9.382558e+00  1.687534e+01
#
#                  V5            V6            V7            V8            V9  \
# count  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean   1.021879e-15  1.494498e-15 -5.620335e-16  1.149614e-16 -2.414189e-15
# ...

# %%
import matplotlib.pyplot as plt

df["Class"].value_counts().plot(kind="bar")
plt.show()

# %%
df["Amount"].plot(kind="hist", bins=50)
plt.show()

# %%
import seaborn as sns

plt.figure(figsize=(6,4))
sns.boxplot(x="Class", y="Amount", data=df)
plt.show()

# %%
df["Time"].plot(kind="hist", bins=50)
plt.show()

# %%
X = df.drop("Class", axis=1)
y = df["Class"]

# %%
X.shape, y.shape
# Out:
# ((284807, 30), (284807,))

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(
    X, y, 
    test_size=0.2, 
    stratify=y, 
    random_state=42
)

# %%
X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((227845, 30), (56962, 30), (227845,), (56962,))

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()

X_train["Amount"] = scaler.fit_transform(X_train[["Amount"]])
X_test["Amount"] = scaler.transform(X_test[["Amount"]])

# %%
X_train["Amount"].describe()
# Out:
# count    2.278450e+05
# mean     3.742243e-17
# std      1.000002e+00
# min     -3.516894e-01
# 25%     -3.291944e-01
# 50%     -2.639429e-01
# 75%     -4.262209e-02
# max      1.021170e+02
# Name: Amount, dtype: float64

# %%
from sklearn.linear_model import LogisticRegression

model = LogisticRegression(max_iter=1000, random_state=42)
model.fit(X_train, y_train)
# Out:
# C:\Users\shrey\credit-card-fraud-detection\venv\Lib\site-packages\sklearn\linear_model\_logistic.py:406: ConvergenceWarning: lbfgs failed to converge after 1000 iteration(s) (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT
#
# Increase the number of iterations to improve the convergence (max_iter=1000).
# You might also want to scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression(max_iter=1000, random_state=42)

# %%
model
# Out:
# LogisticRegression(max_iter=1000, random_state=42)

# %%
y_pred = model.predict(X_test)

# %%
import pandas as pd
pd.Series(y_pred).value_counts()
# Out:
# 0    56878
# 1       84
# Name: count, dtype: int64

# %%
from sklearn.metrics import confusion_matrix

confusion_matrix(y_test, y_pred)
# Out:
# array([[56848,    16],
#        [   30,    68]])

# %%
from sklearn.metrics import classification_report

print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     56864
#            1       0.81      0.69      0.75        98
#
#     accuracy                           1.00     56962
#    macro avg       0.90      0.85      0.87     56962
# weighted avg       1.00      1.00      1.00     56962

# %%
from sklearn.linear_model import LogisticRegression

model_w = LogisticRegression(
    max_iter=2000,
    class_weight="balanced",
    random_state=42
)

model_w.fit(X_train, y_train)
# Out:
# C:\Users\shrey\credit-card-fraud-detection\venv\Lib\site-packages\sklearn\linear_model\_logistic.py:406: ConvergenceWarning: lbfgs failed to converge after 2000 iteration(s) (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT
#
# Increase the number of iterations to improve the convergence (max_iter=2000).
# You might also want to scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression(class_weight='balanced', max_iter=2000, random_state=42)

# %%
y_pred_w = model_w.predict(X_test)

# %%
from sklearn.metrics import classification_report

print(classification_report(y_test, y_pred_w))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.98      0.99     56864
#            1       0.06      0.92      0.11        98
#
#     accuracy                           0.98     56962
#    macro avg       0.53      0.95      0.55     56962
# weighted avg       1.00      0.98      0.99     56962

# %%
y_proba = model_w.predict_proba(X_test)[:, 1]

# %%
y_proba[:10]
# Out:
# array([7.19505016e-03, 7.12079890e-02, 3.47714341e-04, 1.71036254e-02,
#        9.46684878e-01, 1.60847890e-02, 8.12710678e-04, 2.70343310e-02,
#        7.16634806e-02, 5.76850704e-03])

# %%
import numpy as np

y_pred_03 = (y_proba >= 0.3).astype(int)

# %%
from sklearn.metrics import classification_report

print(classification_report(y_test, y_pred_03))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.94      0.97     56864
#            1       0.03      0.92      0.05        98
#
#     accuracy                           0.94     56962
#    macro avg       0.51      0.93      0.51     56962
# weighted avg       1.00      0.94      0.97     56962

# %%
from sklearn.metrics import roc_auc_score

roc_auc_score(y_test, y_proba)
# Out:
# 0.9722446431442582

# %%
from sklearn.ensemble import RandomForestClassifier

rf = RandomForestClassifier(
    n_estimators=100,
    random_state=42,
    n_jobs=-1
)

rf.fit(X_train, y_train)
# Out:
# RandomForestClassifier(n_jobs=-1, random_state=42)

# %%
y_pred_rf = rf.predict(X_test)

# %%
from sklearn.metrics import classification_report

print(classification_report(y_test, y_pred_rf))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     56864
#            1       0.94      0.82      0.87        98
#
#     accuracy                           1.00     56962
#    macro avg       0.97      0.91      0.94     56962
# weighted avg       1.00      1.00      1.00     56962

# %%
print(classification_report(y_test, y_pred_rf))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     56864
#            1       0.94      0.82      0.87        98
#
#     accuracy                           1.00     56962
#    macro avg       0.97      0.91      0.94     56962
# weighted avg       1.00      1.00      1.00     56962

# %%
y_proba_rf = rf.predict_proba(X_test)[:, 1]

from sklearn.metrics import roc_auc_score
roc_auc_score(y_test, y_proba_rf)
# Out:
# 0.9630272515590367

# %%
import joblib

joblib.dump(rf, "models/random_forest_fraud.pkl")
# Out:
# ['models/random_forest_fraud.pkl']

# %%
joblib.dump(scaler, "models/amount_scaler.pkl")
# Out:
# ['models/amount_scaler.pkl']

# %%
import os
import pandas as pd

print(os.path.exists("data/raw/creditcard.csv"))

df = pd.read_csv("data/raw/creditcard.csv")
df.shape
# Out:
# True
# (284807, 31)

# %%
print(os.path.exists("models/random_forest_fraud.pkl"))
print(os.path.exists("models/amount_scaler.pkl"))
# Out:
# True
# True

# %%
import joblib
import numpy as np

rf = joblib.load("models/random_forest_fraud.pkl")
scaler = joblib.load("models/amount_scaler.pkl")

# take one row
sample = df.drop("Class", axis=1).iloc[[0]].copy()

# scale Amount correctly
sample["Amount"] = scaler.transform(sample[["Amount"]])

rf.predict(sample), rf.predict_proba(sample)
# Out:
# (array([0]), array([[1., 0.]]))

# %%
import os

[f for f in os.listdir(".") if f.endswith(".ipynb")]
# Out:
# ['credit_card_fraud_detection.ipynb']
